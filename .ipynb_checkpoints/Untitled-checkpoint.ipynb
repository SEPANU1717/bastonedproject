# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from string import punctuation
from nltk.corpus import stopwords
import nltk
from nltk.corpus import stopwords
TOP_K = 5

# %%
import nltk
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
word = 'running'
stemmed_word = stemmer.stem(word)
print(stemmed_word)
# Out:
# run

# %%
nltk.download('stopwords')
stop = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("final.csv")

# %%
df.head(4)
# Out:
#                                                Title  \
# 0   JavaScript Frameworks/Libraries (React.js, An...
# 1   JavaScript for Impatient Programmers (Axel Ra...
# 2   Eloquent JavaScript, 3rd Edition: A Modern In...
# 3   Deep JavaScript: Theory and Techniques (Axel ...
#
#                                          Description  \
# 0  A collection of JavaScript Frameworks/Librarie...
# 1  This book makes JavaScript less challenging to...
# 2  Eloquent JavaScript dives deep into the JavaSc...
# 3  In depth knowledge of JavaScript makes it easi...
#
#                                                 urls
# 0  https://freecomputerbooks.com/webJavaScriptFra...
# 1  https://freecomputerbooks.com/JavaScript-for-I...
# 2  https://freecomputerbooks.com/Eloquent-JavaScr...
# 3  https://freecomputerbooks.com/Deep-JavaScript-...

# %%
def clean_text(text):
    if not isinstance(text, str):
        return ''
    stop = set(stopwords.words('english'))
    text = text.lower()
    text = ''.join([t for t in text if t not in punctuation])
    text = ' '.join([t for t in text.split() if t not in stop])
    return text

# %%
df['clean_Title'] = df['Title'].apply(clean_text)
df['clean_urls'] = df['urls'].apply(clean_text)

# %%
vectorizer = TfidfVectorizer(analyzer='word', lowercase=False)
X = vectorizer.fit_transform(df['clean_Title'])
title_vectors = X.toarray()

# %%
def get_recommendations(title, feature_locate, df, vectors, feature, stop):
    index_of_element = df[df[feature_locate]==title].index.values[0]
    query_vector = vectors[index_of_element]
    cos_sim = cosine_similarity([query_vector], vectors)[0]
    rec_index = cos_sim.argsort()[-11:-1][::-1]
    rec_df = df.iloc[rec_index].reset_index(drop=True)
    rec_df['clean_Description'] = rec_df['clean_Description'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
    return rec_df[['Book_title', 'Author', 'Rating', 'Price', 'clean_Description', feature]]

# %%
book_title = 'JavaScript Frameworks/Libraries (React.js, Angular, Node.js, etc.)'
feature = 'Book'

# %%
def get_recommendations(book_title, query_field, df, vectors, feature, stop):
    query_vector = vectors[df[df[query_field] == book_title].index.values[0]]
    cosine_similarities = cosine_similarity(query_vector.reshape(1, -1), vectors).flatten()
    related_docs_indices = cosine_similarities.argsort()[::-1]
    topk_indices = related_docs_indices[1:TOP_K + 1]
    recommendations = df.iloc[topk_indices].reset_index(drop=True)
    if len(recommendations) == 0:
        recommendations = pd.DataFrame(columns=df.columns)
    recommendations['clean_Description'] = recommendations['Description'].apply(clean_text)
    return recommendations

# %%
def get_recommendations(book_title, query_field, df, vectors, feature, stop):
    recommendations = pd.DataFrame(columns=df.columns)
    query_df = df[df[query_field] == book_title]
    if len(query_df) == 0:
        print("Error: No matches found for book title in query field.")
        return recommendations
    query_vector = vectors[query_df.index.values[0]]
    cosine_similarities = cosine_similarity(query_vector.reshape(1, -1), vectors).flatten()
    related_docs_indices = cosine_similarities.argsort()[::-1]
    topk_indices = related_docs_indices[1:TOP_K + 1]
    recommendations = df.iloc[topk_indices].reset_index(drop=True)
    if len(recommendations) == 0:
        print("Error: No recommendations found for the given book title.")
        return recommendations
    recommendations['clean_Description'] = recommendations['Description'].apply(clean_text)
    return recommendations

# %%
def book_recommend(book, book_df, similarity):
    index = book_df[book_df['Title'] == book].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    recommended_books = []
    for i in distances[1:6]:
        book_title = book_df.iloc[i[0]].Title
        if book_title not in recommended_books and book_title != book:
            recommended_books.append(book_title)
    return recommended_books

# %%
new_df=pd.DataFrame(df,columns=['Title', 'urls','Description' ])

# %%
new_df.head()
# Out:
#                                                Title  \
# 0   JavaScript Frameworks/Libraries (React.js, An...
# 1   JavaScript for Impatient Programmers (Axel Ra...
# 2   Eloquent JavaScript, 3rd Edition: A Modern In...
# 3   Deep JavaScript: Theory and Techniques (Axel ...
# 4   You Don't Know JS Yet: Get Started - 2nd Ed. ...
#
#                                                 urls  \
# 0  https://freecomputerbooks.com/webJavaScriptFra...
# 1  https://freecomputerbooks.com/JavaScript-for-I...
# 2  https://freecomputerbooks.com/Eloquent-JavaScr...
# 3  https://freecomputerbooks.com/Deep-JavaScript-...
# 4  https://freecomputerbooks.com/You-Dont-Know-JS...
#
#                                          Description
# 0  A collection of JavaScript Frameworks/Librarie...
# 1  This book makes JavaScript less challenging to...
# 2  Eloquent JavaScript dives deep into the JavaSc...
# 3  In depth knowledge of JavaScript makes it easi...
# 4  By learning the basic building blocks of progr...

# %%
new_df.isna().sum()
# Out:
# Title          0
# urls           0
# Description    0
# dtype: int64

# %%
new_df["urls"]=new_df["urls"].fillna(0)

# %%
url = list(enumerate(new_df["urls"]))
new_df["urls"] = 0
for i in range(len(url)):
    if pd.isnull(new_df["Title"][url[i][0]]):
        continue  # skip NaN values
    if new_df["urls"][i] == 0:
        x = ("{}/{}".format("https://www.", str("".join(list(new_df["Title"][url[i][0]].split())))))
        new_df["urls"][i] = x
    else:
        new_df["urls"][i] = new_df["urls"][i]
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_2804\3357029343.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["urls"][i] = x

# %%
new_df["urls"]
# Out:
# 0      https://www./JavaScriptFrameworks/Libraries(Re...
# 1      https://www./JavaScriptforImpatientProgrammers...
# 2      https://www./EloquentJavaScript,3rdEdition:AMo...
# 3      https://www./DeepJavaScript:TheoryandTechnique...
# 4      https://www./YouDon'tKnowJSYet:GetStarted-2ndE...
#                              ...
# 869    https://www./PerformanceandEvaluationofLispSys...
# 870             https://www./LispPrimer(ColinAllen,etal)
# 871        https://www./Zen-StyleProgramming(NilsM.Holm)
# 872    https://www./TheLimitsofMathematics(GregoryJ.C...
# 873    https://www./TheCommonLispCookbook(MarcoAntoni...
# Name: urls, Length: 874, dtype: object

# %%
new_df.sample(5)
# Out:
#                                                  Title  \
# 868          Exploring Randomness (Gregory J. Chaitin)
# 363   A Gentle Introduction to symfony: Build Pro W...
# 845   The Perl CD Bookshelf, Version 4.0 - 6 Bestse...
# 503   Applied Spatial Data Analysis with R (Roger S...
# 510   Learn to Program (in Ruby), Second Edition (C...
#
#                                                   urls  \
# 868  https://www./ExploringRandomness(GregoryJ.Chai...
# 363  https://www./AGentleIntroductiontosymfony:Buil...
# 845  https://www./ThePerlCDBookshelf,Version4.0-6Be...
# 503  https://www./AppliedSpatialDataAnalysiswithR(R...
# 510  https://www./LearntoProgram(inRuby),SecondEdit...
#
#                                            Description
# 868  The book is devoted to a Lisp formalism for ex...
# 363  This book introduces you to the leading framew...
# 845  This collection delivers more than 3,000 pages...
# 503  It presents R packages, functions, classes and...
# 510  Teach you how to program. You'll learn to use ...

# %%
def spliting(text):
  text=str(text).split()
  return text

# %%
new_df['Description']=new_df['Description'].apply(spliting)

# %%
new_df.head()
# Out:
#                                                Title  \
# 0   JavaScript Frameworks/Libraries (React.js, An...
# 1   JavaScript for Impatient Programmers (Axel Ra...
# 2   Eloquent JavaScript, 3rd Edition: A Modern In...
# 3   Deep JavaScript: Theory and Techniques (Axel ...
# 4   You Don't Know JS Yet: Get Started - 2nd Ed. ...
#
#                                                 urls  \
# 0  https://www./JavaScriptFrameworks/Libraries(Re...
# 1  https://www./JavaScriptforImpatientProgrammers...
# 2  https://www./EloquentJavaScript,3rdEdition:AMo...
# 3  https://www./DeepJavaScript:TheoryandTechnique...
# 4  https://www./YouDon'tKnowJSYet:GetStarted-2ndE...
#
#                                          Description
# 0  [A, collection, of, JavaScript, Frameworks/Lib...
# 1  [This, book, makes, JavaScript, less, challeng...
# 2  [Eloquent, JavaScript, dives, deep, into, the,...
# 3  [In, depth, knowledge, of, JavaScript, makes, ...
# 4  [By, learning, the, basic, building, blocks, o...

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
def steming(text):
  l=[]
  for i in text:

    l.append(ps.stem(i))
  return l

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\acer\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\acer\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\acer\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in c:\users\acer\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in c:\users\acer\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: colorama in c:\users\acer\anaconda3\lib\site-packages (from click->nltk) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
new_df.sample(5)
# Out:
#                                                  Title  \
# 784   O'Reilly® High Performance Browser Networking...
# 344             Essential Kotlin (Krzysztof Kowalczyk)
# 430              Design Patterns in C# (Jean Paul V.A)
# 4     You Don't Know JS Yet: Get Started - 2nd Ed. ...
# 736                       Scala Book (Alvin Alexander)
#
#                                                   urls  \
# 784  https://www./O'Reilly®HighPerformanceBrowserNe...
# 344   https://www./EssentialKotlin(KrzysztofKowalczyk)
# 430       https://www./DesignPatternsinC#(JeanPaulV.A)
# 4    https://www./YouDon'tKnowJSYet:GetStarted-2ndE...
# 736             https://www./ScalaBook(AlvinAlexander)
#
#                                            Description
# 784  [This, book, provides, a, hands-on, overview, ...
# 344  [This, book, provides, clear, and, concise, ex...
# 430  [This, book, is, a, companion, to, the, origin...
# 4    [By, learning, the, basic, building, blocks, o...
# 736  [Scala, changes, the, way, you, think, about, ...

# %%
def _join(text):
    return ' '.join(text)

# %%
new_df["Description"] = new_df["Description"].apply(_join)

# %%
new_df['Description'] = new_df['Description'].apply(lambda x: " ".join(x))

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words='english')

# %%
print(cv.get_stop_words())
# Out:
# frozenset({'see', 'anyhow', 'mine', 'have', 'therein', 'has', 'whenever', 'indeed', 'than', 'nine', 'inc', 'often', 'yours', 'were', 'give', 'between', 'upon', 'anyway', 'made', 'cry', 'therefore', 'around', 'whoever', 'in', 'by', 'such', 'hers', 'put', 'or', 'few', 'though', 'we', 'over', 'would', 'us', 'found', 'whole', 'even', 'twenty', 'should', 'mill', 'any', 'back', 'fifteen', 'off', 'him', 'about', 'couldnt', 'fire', 'also', 'whose', 'thereupon', 'am', 'this', 'nor', 'how', 'against', 'next', 'every', 'could', 'these', 'un', 'whom', 'wherein', 'became', 'another', 'i', 'ours', 'they', 'amongst', 'becoming', 'either', 'anything', 'below', 'several', 'last', 'eleven', 'full', 'per', 'been', 'done', 'two', 'are', 'he', 'five', 'sometime', 'etc', 'less', 'here', 'being', 'get', 'bottom', 'many', 'front', 'may', 'my', 'together', 'them', 'towards', 'find', 'nowhere', 'ie', 'on', 'whereupon', 'whence', 'move', 'yourselves', 'while', 'beforehand', 'was', 'four', 'elsewhere', 'if', 'thus', 'without', 'twelve', 'yourself', 'alone', 'still', 'take', 'whither', 'hereupon', 'please', 'namely', 'will', 'thereafter', 'for', 'had', 'behind', 'thereby', 'more', 'else', 'you', 'herself', 'three', 'anyone', 'one', 'at', 'rather', 'where', 'since', 'afterwards', 'do', 'onto', 'too', 'co', 'whereafter', 'something', 'other', 'seems', 'whatever', 'herein', 'seeming', 'himself', 'across', 'but', 'and', 'wherever', 'as', 'now', 'formerly', 'who', 'yet', 'the', 'perhaps', 'call', 'until', 'whether', 'moreover', 'much', 'enough', 'interest', 'somehow', 'from', 'first', 'becomes', 'mostly', 'under', 'a', 'out', 'themselves', 'might', 'hereafter', 'that', 'anywhere', 'hundred', 'both', 'least', 'hasnt', 'among', 'myself', 'con', 'amount', 'besides', 'fill', 'fifty', 'down', 'an', 'due', 'some', 'which', 'meanwhile', 'its', 'cannot', 'latter', 'almost', 'hereby', 'those', 'ever', 'before', 'ten', 'whereas', 'forty', 'keep', 'serious', 'thru', 'never', 'then', 'six', 'none', 'amoungst', 'of', 'nobody', 'show', 'through', 'part', 'top', 'up', 'seem', 'someone', 'seemed', 'because', 'former', 'name', 'ltd', 'via', 'nevertheless', 'when', 'become', 'into', 'again', 'what', 'along', 'their', 'after', 'neither', 'eight', 'ourselves', 'empty', 'beyond', 'everyone', 'however', 'itself', 're', 'our', 'must', 'de', 'sometimes', 'his', 'although', 'eg', 'same', 'your', 'thence', 'there', 'within', 'above', 'third', 'everywhere', 'well', 'during', 'why', 'once', 'hence', 'everything', 'somewhere', 'she', 'is', 'throughout', 'toward', 'further', 'thick', 'very', 'detail', 'me', 'nothing', 'except', 'whereby', 'with', 'own', 'describe', 'latterly', 'it', 'can', 'others', 'to', 'sincere', 'her', 'otherwise', 'bill', 'be', 'only', 'so', 'cant', 'go', 'all', 'beside', 'always', 'no', 'already', 'most', 'side', 'not', 'each', 'sixty', 'thin', 'system', 'noone'})

# %%
from sklearn.feature_extraction.text import CountVectorizer
text_data = df['Description'].values.astype('U')
cv = CountVectorizer()
data = cv.fit_transform(text_data).toarray()

# %%
text_data = df['Description'].values.astype('U')

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(data)

# %%
def book_recommend(book):
    index = new_df[new_df['Title'] == book].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:8]:

      
      print("{} {}".format(new_df.iloc[i[0]].Title,new_df.iloc[i[0]].urls))

# %%
book_recommend(" PHP Essentials (Neil Smyth)")
# Out:
#  JavaScript Essentials (Neil Smyth) https://www./JavaScriptEssentials(NeilSmyth)
#  The PHP Anthology: 101 Essential Tips, Tricks & Hacks, 2nd Edition https://www./ThePHPAnthology:101EssentialTips,Tricks&Hacks,2ndEdition
#  MongoDB 3 Succinctly (Zoran Maksimovic) https://www./MongoDB3Succinctly(ZoranMaksimovic)
#  iOS 8 App Development Essentials: Develop iOS 8 Apps in Swift https://www./iOS8AppDevelopmentEssentials:DevelopiOS8AppsinSwift
#  JavaScript: The First 20 Years (Allen Wirfs-Brock, et al) https://www./JavaScript:TheFirst20Years(AllenWirfs-Brock,etal)
#  Scientific and Engineering Applications Using MATLAB (E. P. Leite) https://www./ScientificandEngineeringApplicationsUsingMATLAB(E.P.Leite)
#  SQL Performance Explained: Everything Developers Need to Know https://www./SQLPerformanceExplained:EverythingDevelopersNeedtoKnow

# %%
import pickle

# %%
pickle.dump(new_df,open("book_recm.pkl","wb"))
pickle.dump(similarity,open("similarity.pkl","wb"))

# %%
np.array(new_df["Title"])
# Out:
# array([' JavaScript Frameworks/Libraries (React.js, Angular, Node.js, etc.)',
#        ' JavaScript for Impatient Programmers (Axel Rauschmayer)',
#        ' Eloquent JavaScript, 3rd Edition: A Modern Introduction',
#        ' Deep JavaScript: Theory and Techniques (Axel Rauschmayer)',
#        " You Don't Know JS Yet: Get Started - 2nd Ed. (Kyle Simpson)",
#        " You Don't Know JS Yet: Scope and Closures, 2nd Edition",
#        ' JavaScript: The First 20 Years (Allen Wirfs-Brock, et al)',
#        ' Mostly Adequate Guide To Functional Programming in JavaScript',
#        ' Structure and Interpretation of Computer Programs in JavaScript',
#        ' Oh My JavaScript: The Best JavaScript Articles (Azat Mardan)',
#        ' The Recursive Book of Recursion using JavaScript (Al Sweigart)',
#        ' Understanding ECMAScript 6 (Nicholas C. Zakas)',
#        ' Functional-Light JavaScript (Kyle Simpson)',
#        ' Building Front-End Web Apps with Plain JavaScript (Gerd Wagner)',
#        " Learning JavaScript Design Patterns: A Developer's Guide",
#        ' Understanding the DOM - Document Object Model (Tania Rascia)',
#        ' Speaking JavaScript: An In-Depth Guide for Programmers',
#        ' Object-Oriented JavaScript, 2nd Edition (Stoyan Stefanov, et al.)',
#        ' JavaScript Enlightenment: Grokking Modern JavaScript',
#        " You Don't Know JS Yet: ES.Next & Beyond",
#        " You Don't Know JS Yet: Async & Performance",
#        " You Don't Know JS Yet: Objects and Classes",
#        " You Don't Know JS Yet: Types and Grammar",
#        ' Exploring ES6: Upgrade to the Next Version of JavaScript',
#        ' Deep Learning with JavaScript: Neural Networks in TensorFlow.js',
#        ' Neural Networks with JavaScript Succinctly (James McCaffrey )',
#        ' The Past, Present, and Future of JavaScript (Axel Rauschmayer)',
#        ' JavaScript Essentials (Neil Smyth)',
#        ' Programming Persistent Memory: A Comprehensive Guide',
#        ' Exploring ES2018 and ES2019 (Axel Rauschmayer)',
#        ' Exploring ES2016 and ES2017 (Axel Rauschmayer)',
#        ' The JavaScript Way (Baptiste Pesquet)',
#        ' Practical Modern JavaScript: Dive into ES6 and the Future',
#        ' ECMAScript 6 Succinctly (Matthew Duffield)',
#        " O'Reilly® High Performance Browser Networking (Ilya Grigorik)",
#        ' Composing Software: Functional and Object in JavaScript',
#        ' WebGL Insights (Patrick Cozzi)',
#        " O'Reilly® The Problem with Native JavaScript APIs (N. C. Zakas)",
#        ' The TypeScript Handbook (Microsoft)',
#        ' Tackling TypeScript: Upgrading from JavaScript',
#        ' TypeScript in 50 Lessons (Stefan Baumgartner)',
#        ' TypeScript Deep Dive (Basarat Ali Syed)',
#        ' TypeScript Succinctly: The .NET approach to JavaScript',
#        ' TypeScript Accelerated (James Porter)',
#        ' TypeScript for C# Programmers (Steve Fenton)',
#        ' Human JavaScript: For Simple but Powerful JavaScript Apps',
#        ' JavaScript For Cats (Maxwell Ogden)',
#        ' Web Applications with Javascript or Java (Gerd Wagner, et al)',
#        ' Next Generation HTML5 and JavaScript (InfoQ)',
#        ' Modern Web Essentials Using JavaScript and HTML5 (David Pitt)',
#        ' ppk on JavaScript (Peter-Paul Koch)',
#        ' JavaScript Allong (Reginald Braithwaite)',
#        " O'Reilly® JavaScript and HTML5 Now (Kyle Simpson)",
#        ' HTML Canvas Deep Dive (Josh Marinacci)',
#        ' Essential HTML5 Canvas (Krzysztof Kowalczyk)',
#        ' Sams Teach Yourself JavaScript in 24 Hours, 4th Edition',
#        ' Developing Single Page Web Apps with Backbone.js (Prateek Dayal)',
#        ' Recipes with Angular.js (Frederik Dietz)',
#        ' Express.js Guide: The Comprehensive Book on Express.js',
#        " O'Reilly® Developing Backbone.js Applications (Addy Osmani)",
#        ' Node.js Succinctly (Agus Kurniawan)',
#        ' AngularJS Succinctly (Frederik Dietz)',
#        " O'Reilly® Interactive Data Visualization for the Web",
#        ' Twitter Bootstrap 3 Succinctly (Peter Shaw)',
#        ' Twitter Bootstrap Succinctly: Design Attractive, Consistent UIs',
#        ' D3 Tips and Tricks: Interactive Data Visualization in Web Browsers',
#        ' Leaflet Tips and Tricks: Interactive Maps with leaflet.js',
#        ' JavaScript: The Right Way (William Oliveira)',
#        " O'Reilly® Node: Up and Running - Scalable Server-Side Code",
#        ' The Node Beginner Book: A Comprehensive Node.js Tutorial',
#        ' AngularJS Fundamentals In 60-ish Minutes (Dan Wahlin)',
#        " O'Reilly® JS.next: A Manager's Guide (Aaron Frost)",
#        ' Knockout.js Succinctly (Ryan Hodson)',
#        ' JavaScript Succinctly (Cody Lindley)',
#        ' Building Blockchain Projects (Narayan Prusty)',
#        ' DOM Enlightenment (Cody Lindley)',
#        ' jQuery Succinctly (Cody Lindley)',
#        ' Backbone Tutorials (Thomas Davis)',
#        ' Programming Windows 8 Apps with HTML, CSS & JavaScript',
#        ' Building Android Apps with HTML, CSS & JavaScript, 2nd Edition',
#        " Mixu's Node Book: A Book About Using Node.js (M. Takada)",
#        ' Go for Javascript Developers (Maor Zamski, et al)',
#        ' Gulp Succinctly (Kris van der Mast)',
#        ' jQuery Fundamentals (Rebecca Murphey)',
#        ' WordPress and Ajax: An In-depth Guide (Ronald Huereca)',
#        " O'Reilly® What Is Node? JavaScript Breaks Out of the Browser",
#        ' Building iPhone Apps with HTML, CSS, and JavaScript',
#        ' Essential JavaScript and JQuery Design Patterns (Osmani)',
#        ' Google Maps API Tutorial (Mike Williams)',
#        ' The Web Book: Guide to HTML, CSS, JavaScript, PHP and MySQL',
#        ' Building A JavaScript Framework (Alex Young)',
#        ' Adobe Integrated Runtime (AIR) for JavaScript Developers',
#        ' Testing with CoffeeScript (Jack Franklin)',
#        ' Smooth CoffeeScript (E. Hoigaard)',
#        " O'Reilly® The Little Book on CoffeeScript (Alex MacCaw)",
#        " O'Reilly® JavaScript Cookbook: Programming the Web",
#        " O'Reilly® Modern JavaScript: A Curated Collection",
#        " O'Reilly® Programming 3D Applications with HTML5 and WebGL",
#        " O'Reilly® Dojo: The Definitive Guide (Matthew A. Russell)",
#        " O'Reilly® Web Audio API (Boris Smus)",
#        " O'Reilly® Programming JavaScript Applications (Eric Elliott)",
#        ' Beyond the Basic Stuff with Python: Writing Clean Code',
#        ' Python Packages (Tomas Beuzen, et al.)',
#        ' Deep Learning with Python, 2nd Edition (Francois Chollet)',
#        ' Architecture Patterns with Python (Harry Percival, et al.)',
#        ' Clean Architectures in Python: Better Software Design',
#        ' Automate the Boring Stuff with Python (Albert Sweigart)',
#        ' Python for Everybody: Exploring Data in Python 3',
#        ' Problem Solving with Algorithms/Data Structures using Python',
#        ' Fundamentals of Python Programming (Richard L. Halterman)',
#        " O'Reilly® Think Python, 2nd Edition (Allen B. Downey)",
#        ' The Big Book of Small Python Projects: 81 Easy Practice Programs',
#        ' Practical Python Projects (Yasoob Khalid)',
#        ' Python Programming Exercises, Gently Explained (Al Sweigart)',
#        ' Functional Programming in Python (David Mertz)',
#        ' Python 3 Patterns, Recipes and Idioms (Bruce Eckel, et al)',
#        ' The Recursive Book of Recursion using Python (Al Sweigart)',
#        " O'Reilly® Python Data Science Handbook: Essential Tools",
#        ' Modeling and Simulation in Python (Allen B. Downey)',
#        ' Introduction to Scientific Programming with Python',
#        ' Python for Network Engineers (Natasha Samoylenko)',
#        ' Programming for Computations - Python 3 Edition',
#        ' Computational Physics with Python (Eric Ayars)',
#        ' Python Design Patterns (Brandon Rhodes)',
#        " O'Reilly® 20 Python Libraries You Aren't Using (But Should)",
#        " O'Reilly® Think Bayes: Bayesian Statistics in Python",
#        ' How To Code in Python 3 (Lisa Tagliaferri)',
#        ' Python Tutorial (Guido van Rossum)',
#        ' How to Think Like a Computer Scientist: Learning with Python 3',
#        " The Coder's Apprentice: Learning Programming with Python 3",
#        ' Code Like a Pythonista: Idiomatic Python (David Goodger)',
#        ' Learn More Python 3 The Hard Way (Zed A. Shaw)',
#        ' Create Graphical User Interfaces with Python (Laura Sach, et al)',
#        ' Foundations of Robotics: Approach with Python and ROS',
#        " O'Reilly® Think DSP: Digital Signal Processing in Python",
#        ' PySDR: A Guide to SDR and DSP using Python (Marc Lichtman)',
#        ' Kalman and Bayesian Filters in Python (Roger R Labbe Jr.)',
#        ' Python for Geospatial Analysis (Ujaval Gandhi)',
#        ' Python Scripting for Spatial Data Processing (Pete Bunting, et al)',
#        ' Learning Python (Fabrizio Romano)',
#        ' Mining Social Media using Python: Finding Stories in Data',
#        ' Python Machine Learning Projects (Brian Boucheron, et al)',
#        ' Deep Learning with PyTorch (Eli Stevens, et al)',
#        ' Machine Learning with TensorFlow (Nishant Shukla)',
#        ' Elements of Data Science using Python (Allen B. Downey)',
#        ' Biopython Tutorial and Cookbook (Jeff Chang, et al)',
#        ' Building Skills in Object-Oriented Design in Python',
#        ' Program Arcade Games: With Python and Pygame (Paul Craven)',
#        ' Coding Games With Pygame Zero and Python (Richard Smith)',
#        ' Code the Classics – Volume 1: Using Python and Pygame',
#        ' Learning Computing with Robots using Python (Deepak Kumar)',
#        ' Classic Computer Science Problems in Python (David Kopec)',
#        ' CS for All: An Introduction to Computer Science using Python',
#        ' Practices of the Python Pro (Dane Hillard)',
#        ' IPython Interactive Computing and Visualization Cookbook',
#        ' A Whirlwind Tour of Python (Jake VanderPlas)',
#        " Learn Python, Break Python: A Beginner's Guide to Programming",
#        ' Annotated Algorithms in Python: with Applications',
#        " O'Reilly® Test-Driven Development with Python (Harry Percival)",
#        " Non-Programmer's Tutorial for Python 3 (Josh Cogliati, et al)",
#        " The Hitchhiker's Guide to Python: Best Practices for Development",
#        ' Cracking Codes with Python: Building and Breaking Ciphers',
#        ' Open Workbook of Cryptology: Python Projects',
#        ' Python and Coding Theory (David Joyner)',
#        ' Hands-on Python Tutorial (Dr. Andrew N. Harrington)',
#        ' Essential Python (Krzysztof Kowalczyk)',
#        " O'Reilly® Python Web Frameworks (Carlos De La Guardia)",
#        ' Hadoop with Python (Zachary Radtka, et al)',
#        ' Python Notes for Professionals (Stack Overflow Contributors)',
#        ' How to Make Mistakes in Python? (Mike Pirnat)',
#        ' Fast Lane to Python (Norm Matloff)',
#        " A Beginner's Python Tutorial (Wikibooks)",
#        ' Programming for Computations - Python (Svein Linge, et al)',
#        ' Solving PDEs in Python: The FEniCS Tutorial I (H. Langtangen)',
#        ' Developing Graphics Frameworks with Python and OpenGL',
#        ' Python and OpenGL for Scientific Visualization (Nicolas P. Rougier)',
#        ' Scientific Visualisation: Python and Matplotlib (Nicolas P. Rougier)',
#        ' From Python to NumPy (Nicolas P. Rougier)',
#        ' Guide to NumPy (Travis E. Oliphant)',
#        ' NumPy Tutorials (Usman Malik, Anne Bonner, et al)',
#        ' Scipy Lecture Notes (Emmanuelle Gouillart, et al)',
#        ' SciPy Programming Succinctly (James McCaffrey)',
#        ' Bayesian Methods for Hackers: Using Python and PyMC',
#        " O'Reilly® Picking a Python Version: A Manifesto (David Mertz)",
#        ' Dive Into Python 3 (Mark Pilgrim)',
#        ' Porting to Python 3: An In-depth Guide (Lennart Regebro)',
#        ' Python Scripting for Spatial Data Processing (Pete Bunting, et al)',
#        ' Python 3 Basics Tutorial (Kristian Rother)',
#        ' Modeling Creativity - Case Studies in Python (Tom De Smedt)',
#        ' Python 201: (Slightly) Advanced Python Topics (Dave Kuhlman)',
#        ' Python for Informatics: Exploring Information (Charles Severance)',
#        ' Algorithmic Problem Solving with Python (John B. Schneider)',
#        ' Python for Econometrics, Statistics and Data Analysis',
#        ' The Full Stack Python (Matt Makai)',
#        " O'Reilly® Natural Language Processing with Python",
#        ' Hands-On Natural Language Processing with Python',
#        ' Think Stats, 2nd Edition: Exploratory Data Analysis in Python',
#        ' Gui Programming With Python: Using the Qt Toolkit (B. Rempt)',
#        ' Deep Learning Tutorials using Python (LISA Lab)',
#        ' Python for Kids: A Playful Introduction to Programming',
#        ' Hacking Secret Ciphers with Python (Albert Sweigart)',
#        ' Think Python - How to Think Like a Computer Scientist',
#        ' Open Data Structures: An Introduction using Python (Pat Morin)',
#        ' Programming Computer Vision with Python: Tools and Algorithms',
#        ' Invent Your Own Computer Games with Python, 3rd Edition',
#        ' Learn to Program Using Python: A Tutorial for Hobbyists, Starters',
#        ' Introduction to Python for Computational Science and Engineering',
#        ' Python Scripting for Computational Science (Hans Langtangen)',
#        ' Python Succinctly (Jason Cannon)',
#        ' The Python Language Reference Manual (Guido van Rossum, et al)',
#        ' A Practical Introduction to Python Programming (Brian Heinold)',
#        ' An Introduction to Python (Guido van Rossum)',
#        ' Python for You and Me (Kushal Das)',
#        ' Make Games with Python on Raspberry Pi (Sean M. Tracey)',
#        " O'Reilly® Mining the Social Web, 2nd Edition (Matthew A. Russell)",
#        " O'Reilly® Think Stats: Probability and Statistics using Python",
#        " O'Reilly® The Python Standard Library (Fredrik Lundh)",
#        ' Learning to Program Using Python (Cody Jackson)',
#        ' Programming and Mathematical Thinking: Discrete Math & Python',
#        ' Keras Succinctly (James McCaffrey)',
#        ' Dive Into Python: Python from Novice to Pro (Mark Pilgrim)',
#        ' A Byte of Python (Swaroop C H)', ' A Python Book (Dave Kuhlman)',
#        ' Text Processing in Python (David Mertz)',
#        ' Making Games with Python and Pygame (Albert Sweigart)',
#        ' Effective Django (Nathan Yergler)',
#        ' The Definitive Guide to Django: Web Development Done Right',
#        " O'Reilly® Think Complexity: Science and Modeling (Allen Downey)",
#        ' Computational Physics with Python (Mark Newman)',
#        ' Python Scientific Lecture Notes (Scipy Lectures )',
#        ' Inventory Analytics: A Practicable, Python-Driven Approach',
#        ' Python in Hydrology (Sat Kumar Tomer)',
#        ' How To Write Your Own Software Using Python (Steven F. Lott)',
#        ' First Course in Programming with Karel the Robot and Python',
#        ' Basic Data Analysis and More - A Guided Tour Using Python',
#        " Become a Code Breaker with Python: a Beginner's Guide",
#        ' The Art and Craft of Programming, Python Edition (John C. Lusth)',
#        ' Learning with Python: Interactive Edition',
#        ' Learning to Program with Python (Richard L. Halterman)',
#        ' Design Patterns in Python (Alexander Shvets, et al)',
#        " O'Reilly® Python Cookbook, 3rd Ed: Recipes for Mastering Python 3",
#        " Building Skills in Python: A Programmer's Introduction to Python",
#        ' Fundamentals of Programming: With OOP, Python Edition',
#        ' The Definitive Guide to Pylons (James Gardner)',
#        ' Data Structures and Algorithms with OPP Design Patterns in Python',
#        ' Start Here: Python Programming for Beginners (Jody S. Ginther)',
#        ' How To Code in Go (Mark Bates, et al)',
#        ' Go Bootcamp: Everything You Need to Know to Get Started with Go',
#        ' The Way To Go: An Introduction To The Go Programming Language',
#        ' Effective Go (Robert Griesemer, et al)',
#        ' The Little Go Book (Karl Seguin)', ' Go Succinctly (Mark Lewin)',
#        ' Essential Go (Krzysztof Kowalczyk)',
#        ' Go 101: Focusing on Go Syntax/Semantics Details (Tapir Liu)',
#        ' Go for Javascript Developers (Maor Zamski, et al)',
#        ' Building Web Apps with Go (Jeremy Saenz)',
#        ' Go Web Development Succinctly (Mark Lewin)',
#        ' Practical Cryptography With Go (Kyle Isom)',
#        ' Network Programming with Go (Jan Newmarch)',
#        ' An Introduction to Programming in Go (Caleb Doxsey)',
#        ' Go Programming (John P. Baugh)',
#        ' Go by Example (Mark McGranaghan)',
#        ' Go Data Structures and Algorithms (Christopher Fox)',
#        ' Dynamic Proxies in Java (Heinz M. Kabutz)',
#        ' The Java Web Scraping Handbook (Kevin Sahin)',
#        ' Naked Objects (Richard Pawson, et al)',
#        ' Java Transaction Design Strategies (Mark Richards)',
#        ' Playing with Java Microservices on Kubernetes and OpenShift',
#        ' Object-Oriented vs. Functional Programming (R. Warburton)',
#        ' High-Performance Java Platform Computing',
#        ' Docker for Java Developers (Arun Gupta)',
#        ' OSGi In Practice (Neil Bartlett)',
#        ' Building Reactive Microservices in Java (Clement Escoffier)',
#        ' Microservices for Java Developers: Frameworks and Containers',
#        ' Microservices Best Practices for Java (Michael Hofmann, et al)',
#        ' Developing Reactive Microservices: Implementation in Java',
#        ' RESTful Java with JAX-RS 2.0: Designing and Developing',
#        ' Real-World Maintainable Java Software (Abraham Marin-Perez)',
#        " The Java Native Interface: Programmer's Guide and Specification",
#        ' The JHipster Mini-Book (Matt Raible)',
#        ' Practical Guide to Building an API Back End with Spring Boot',
#        ' The Java Garbage Collection Mini-Book (Charles Humble)',
#        ' Migrating Java to the Cloud (Jason Goodwin, et al)',
#        ' What Every Programmer Should Know About Memory',
#        ' Software Architecture with Spring 5.0 (Rene Enriquez, et al)',
#        ' 3D Game Development with LWJGL 3 (Antonio H. Bejarano)',
#        ' Processing XML with Java: A Guide to SAX, DOM, JDOM, JAXP',
#        ' Java Based Real Time Programming (Klas Nilsson)',
#        ' BIG CPU, BIG DATA: Solving Toughest Problems in Java',
#        ' Java Authentication and Authorization Service (JAAS) in Action',
#        ' Spring Framework Cookbook (JCGs)',
#        ' Spring by Example (David Winterfeldt, et al)',
#        ' Practical Artificial Intelligence Programming in Java (Mark Watson)',
#        " The Common Java Cookbook (Tim O'Brien)",
#        ' The Java Game Development Tutorial (Fabian Birzele)',
#        ' Apache Jakarta Commons: Reusable Java Components (Iverson)',
#        ' Modern Java EE Design Patterns: Building Scalable Architecture',
#        ' Java Design Patterns (Rohit Joshi)',
#        ' Java Design Pattern: A Tutorial (James W. Cooper)',
#        ' Java Application Development on Linux (Carl Albing, et al)',
#        " O'Reilly® RxJava for Android App Development (K. Matt Dupree)",
#        ' Reactive Programming on Android with RxJava (C. Arriola, et al)',
#        ' Pro Java 6 3D Game Development: Java 3D, JOGL, JInput and JOAL',
#        ' Java Game Development Tutorials (Fabian Birzele, et al.)',
#        ' Getting Started with the Java 3D API (Dennis J. Bouvier)',
#        ' UML for Java Programmers (Robert Cecil Martin)',
#        ' Java Persistence (Wikibooks)',
#        ' Guide to Java Persistence and Hibernate (S. Hennebrueder)',
#        ' How to Design Classes (Matthias Felleisen, et al)',
#        ' AI Algorithms, Data Structures, and Idioms in Prolog, Lisp, and Java',
#        " O'Reilly® Killer Game Programming in Java (Andrew Davison)",
#        ' A Brief Introduction to Neural Networks using Java',
#        ' InfoQ eMag: Java 8 (InfoQ)',
#        ' Concurrent Programming: The Java Programming Language',
#        ' TCP/IP Sockets in Java, 2nd Ed: Practical Guide for Programmers',
#        ' CICS and the JVM server: Developing and Deploying Java Apps',
#        ' Java Application Development for CICS (Chris Rayns, et al)',
#        ' Building Skills in Object-Oriented Design (in Java and Python)',
#        ' The ABC of PDF with iText: PDF Syntax Essentials (Bruno Lowagie)',
#        ' Essentials of the Java Programming Language: A Hands-On Guide',
#        " QuickTime for Java: A Developer's Notebook (Chris Adamson)",
#        ' SCJP: Sun Certified Programmer for Java Platform Study Guide',
#        ' SCJP Sun Certified Programmer for Java 6 Exam 310-065',
#        " A Programmer's Guide to Java SCJP Certification: A Primer",
#        ' Functional Programming in Java: Java 8 Lambda Expressions',
#        ' Programming Neural Networks with Encog3 in Java (Jeff Heaton)',
#        ' Introduction to Neural Networks with Java (Jeff Heaton)',
#        ' HTTP Programming Recipes for Java Bots (Jeff Heaton)',
#        ' Compiling Scala for the Java Virtual Machine (Michel Schinz)',
#        ' Java Testing and Design: From Unit Testing to Automated Web Tests',
#        ' J2ME and Gaming (Jason Lam)',
#        ' Modern Multithreading using Java, C++, and Win32 Programs',
#        ' Complete Java 2 Certification Study Guide, 5th Edition',
#        ' 1000 Java Tips (Alexandre Patchine, Dr. Heinz M. Kabutz)',
#        ' Virtual Machine Design and Implementation in C/C++',
#        ' JNDI API Tutorial: Building Directory-Enabled Java Applications',
#        " O'Reilly® Beyond Java (Bruce Tate)",
#        ' The Java Enterprise CD Bookshelf, 7 Bestselling Books',
#        ' The Java Reference Library Bookshelf, 5 Bestselling Books',
#        ' Elements of Kotlin (Mark L. Murphy)',
#        ' Kotlin Quick Reference (Alvin Alexander)',
#        ' Learning Kotlin (Stack Overflow Contributors)',
#        ' Elements of Kotlin Coroutines (Mark L. Murphy)',
#        ' Kotlin in Action (Dmitry Jemerov, et al)',
#        ' Essential Kotlin (Krzysztof Kowalczyk)',
#        ' Kotlin™ Notes for Professionals',
#        ' Kotlin/Android Studio Development Essentials (Neil Smyth)',
#        ' PHP Pandas: The PHP Programming Language for Everyone',
#        ' Practical PHP: The Definitive Guide to Programming PHP',
#        ' PHP Essentials (Neil Smyth)',
#        ' PHP Power Programming (Andi Gutmans, Stig Bakken, et al)',
#        ' Essential PHP (Krzysztof Kowalczyk)',
#        ' Survive The Deep End: PHP Security (Padraic Brady)',
#        ' Upgrading to PHP 7 (Davey Shafik)',
#        ' PHP: The Right Way (Phil Sturgeon/Josh Lockhart)',
#        ' PHP Notes for Professionals',
#        ' Functional PHP: The Art of Functional Composition (Luis Atencio)',
#        ' PHP Programming (Penn Wu)', ' PHP Programming (Wikibooks)',
#        ' PHP 101: PHP For the Absolute Beginner (Vikrami Vaswani)',
#        ' PHP Succinctly (Jose Roberto Olivas Mendoza)',
#        " O'Reilly® PHP Cookbook (David Sklar, Adam Trachtenberg)",
#        ' The Missing Link: An Introduction to Web Programming',
#        ' A Gentle Introduction to symfony: Build Pro Websites Faster',
#        ' Code Bright - Web Development with the Laravel Framework',
#        ' Drupal 7 Views Cookbook (J. Ayen Green)',
#        " O'Reilly® High Performance Drupal: Fast and Scalable Sites",
#        ' The Definitive Guide to symfony (Fabien Potencier, et al)',
#        " Programmer's Guide To Building Testable PHP Applications",
#        ' RESTful PHP Web Services (Samisa Abeysinghe)',
#        ' PHP Best Practices: A Guide for Common and Confusing PHP Tasks',
#        ' The PHP Anthology: 101 Essential Tips, Tricks & Hacks, 2nd Edition',
#        ' Doctrine ORM for PHP (Jonathan H. Wage, Konsta Vesterinen)',
#        ' The Oracle PHP Cookbook (John Alphonse, Justin Kestelyn)',
#        ' The Underground PHP and Oracle Manual (Christopher Jones, et al)',
#        ' The Web Book: Guide to HTML, CSS, JavaScript, PHP and MySQL',
#        ' Super Awesome Advanced CakePHP Tips ©2009 (Matt Curry)',
#        ' Zend Framework: Surviving The Deep End (P?draic Brady)',
#        ' PHP Reference: Beginner to Intermediate PHP5 (Mario Lurig)',
#        ' The PEAR Installer Manifesto: How to Revolutionize Your PHP Apps',
#        ' Building Online Communities with phpBB 2 (Jeremy Rogers, et al)',
#        ' AJAX and PHP: Building Responsive Web Applications (C. Darie)',
#        " O'Reilly® PHPUnit Pocket Guide (Sebastian Bergmann)",
#        ' Intrusion Detection Systems with Snort, Apache, MySQL, PHP, ACID',
#        " O'Reilly® The Web Programming CD Bookshelf Version 1.0",
#        ' PHP Programming', " Thinking in C# (Larry O'Brien, et al)",
#        ' Fundamentals of Computer Programming with C# (Svetlin Nakov)',
#        ' Developing on AWS with C#: Using C# to Build Apps on the AWS',
#        ' C# Development - The C# Yellow Book (Rob Miles)',
#        ' C# Essentials (Neil Smyth)',
#        ' Programming Basics with C# (Svetlin Nakov, et al.)',
#        ' Essential C# (Krzysztof Kowalczyk)',
#        ' Object-oriented Programming in C# for C and Java Programmers',
#        ' Object Oriented Programming using C# (Simon Kendal)',
#        ' Guide to NoSQL with Azure Cosmos DB (Gaston C. Hillar, et al)',
#        " Programmer's Heaven C# School Book (Faraz Rasheed, et al)",
#        ' Dissecting a C# Application (Christian Holm, et al)',
#        ' C# 1: Introduction to programming and the C# language',
#        ' C# Programming (Wikibooks)',
#        ' Threading in C# (Joseph Albahari)',
#        ' C# Design Patterns: A Tutorial (James W. Cooper)',
#        ' .NET Book Zero: C#/.NET for C/C++ Developers (Charles Petzold)',
#        ' Under the Hood of .NET Memory Management (Chris Farrell)',
#        ' What Every Programmer Should Know About Memory',
#        ' Pointers and Memory (Nick Parlante, et al.)',
#        ' C# Notes for Professionals',
#        ' Windows Phone 8 Programming in C# (Rob Miles)',
#        ' HTTP Programming Recipes for C# Bots (Jeff Heaton)',
#        ' Domain-Driven Design using C#',
#        ' How to Design Classes (Matthias Felleisen, et al)',
#        ' Object-Oriented Programming in C# Succinctly (Sander Rossel)',
#        ' C# Succinctly (Joe Mayo)',
#        ' Machine Learning Using C# Succinctly (James McCaffrey)',
#        ' Neural Networks Using C# Succinctly (James McCaffrey)',
#        ' Professional C#/VB .NET Coding Guidelines (Steve Sartain)',
#        ' C# Code Contracts Succinctly (Dirk Strauss)',
#        ' MongoDB 3 Succinctly (Zoran Maksimovic)',
#        ' Data Capture and Extraction with C# Succinctly (Ed Freitas)',
#        ' Programming C# for Beginners (Mahesh Chand)',
#        ' Visual Studio for Mac Succinctly (Alessandro Del Sole)',
#        ' Creating Mobile Apps with Xamarin.Forms (Charles Petzold)',
#        ' Agile Principles, Patterns, and Practices in C# (Robert Martin)',
#        ' Programming XML with C# (Mahesh Chand)',
#        ' Beginners Guide to C# and the .NET Micro Framework (Gus Issa)',
#        ' C# Tutorials', ' NHibernate Succinctly (Ricardo Peres)',
#        ' Regular Expressions Succinctly (Joe Booth)',
#        ' TypeScript for C# Programmers (Steve Fenton)',
#        ' Windows Phone Programming in C# (Rob Miles)',
#        ' Design Patterns in C# (Jean Paul V.A)',
#        ' C++ Succinctly: C++ for C# Developers (M. McLaughlin)',
#        ' Real World Functional Programming: With Examples in F# and C#',
#        ' Data Structures and Algorithms with OPP Design Patterns in C#',
#        " Developer's Guide to Microsoft Enterprise Library C# Edition",
#        ' Parallel Programming with Microsoft .NET (Colin Campbell)',
#        ' The C# Station Tutorial (Joe Mayo)',
#        ' Game Development Using Microsoft Xna Game Studio',
#        ' HTTP Programming Recipes for C# Bots (Jeff Heaton)',
#        ' Rapid C# Windows Development (Joseph Chancellor)',
#        ' Standard ECMA-334 C# Language Specification, 4th Edition',
#        ' .NET Compact Framework Programming with C# and Visual Basic',
#        ' Xamarin.Forms Succinctly (Derek Jensen)',
#        ' PDF Succinctly (Ryan Hodson)',
#        ' Sams Teach Yourself C# in 24 Hours (James Foxall, et al)',
#        ' Microsoft Visual C# Express Edition: Build a Program Now!',
#        ' Beginning iOS Programming with Swift (Simon Ng)',
#        ' Swift Algorithms and Data Structures (Wayne Bishop)',
#        ' SwiftUI Essentials - iOS Edition (Neil Smyth)',
#        ' Learn Swift (Aidan Finn)', ' Hacking with Swift (Paul Hudson)',
#        ' Mastering Swift (Jon Hoffman)',
#        ' Essential Swift (Krzysztof Kowalczyk)',
#        ' Swift Notes for Professionals',
#        ' iOS App Development Essentials: Xcode and Swift',
#        ' Swift Pocket Reference: Programming for iOS and OS X',
#        ' Swift by Tutorials: An Hands-On Approach',
#        ' iOS 9 App Development Essentials: Xcode 7 and Swift 2',
#        ' iOS 8 App Development Essentials: Develop iOS 8 Apps in Swift',
#        ' Xcode Tutorial For Beginners (Chris Ching)',
#        ' The Swift Programming Language (Apple)',
#        ' Swift for Ruby Developers: An Tutorial Introduction',
#        ' Test-Driven iOS Development with Swift (Dominik Hauser)',
#        ' Hyperparameter Tuning for Machine and Deep Learning with R',
#        ' Geocomputation with R (Robin Lovelace, et al.)',
#        ' Hands-On Programming with R: Functions and Simulations',
#        ' R Programming for Data Science (Roger D. Peng)',
#        ' R Graphics Cookbook: Practical Recipes for Visualizing Data',
#        ' An Introduction to R (Alex Douglas, et al.)',
#        ' Advanced R, Second Edition (Hadley Wickham)',
#        ' Advanced R Solutions (Malte Grosser, et al)',
#        ' R for Data Science: Visualize, Model, Transform, Tidy, Import',
#        ' R Packages: Organize, Test, Document, and Share Your Code',
#        ' Forecasting, Principles and Practice, Using R (R. J. Hyndman)',
#        ' Introduction to Data Science: Data Analysis and Algorithms with R',
#        ' Regression Models for Data Science in R (Brian Caffo)',
#        ' Efficient R Programming: Practical Guide to Smarter Programming',
#        ' Cookbook for R: Best R Programming TIPs (Winston Chang)',
#        ' Advanced R (Florian Prive)',
#        ' Applied Statistics with R (David Dalpiaz)',
#        ' An Introduction to Statistical Learning: with Applications in R',
#        ' An Introduction to Bayesian Thinking using R',
#        ' Bayes Rules! An Introduction to Applied Bayesian Modeling using R',
#        ' Bayes Factors for Forensic Decision Analyses with R',
#        ' Advanced Data Analysis using R (Cosma R. Shalizi)',
#        ' Introduction to Statistical Thinking, with R, without Calculus',
#        ' Linear Regression Using R: An Introduction to Data Modeling',
#        ' Exploratory Data Analysis with R (Roger D. Peng)',
#        ' Learning Statistics with R (Daniel Navarro)',
#        ' Text Mining with R: A Tidy Approach (Julia Silge, et al)',
#        ' Advanced R Programming (Hadley Wickham)',
#        ' R for Beginners (Sasha D. Hafner)',
#        ' Just Enough R: Learn Data Analysis with R in a Day (S. Raman)',
#        ' The R Inferno (Patrick Burns)',
#        ' The Art of R Programming: A Tour of Statistical Software Design',
#        ' A Step-by-Step R Tutorial: Applications and Programming',
#        ' Analyzing Linguistic Data: Introduction to Statistics using R',
#        ' Statistical Foundations of Machine Learning using R',
#        ' Statistics with R (Vincent Zoonekynd)',
#        ' Introduction to Probability and Statistics Using R (G. Jay Kerns)',
#        ' R Succinctly (Barton Poulson)',
#        ' Using R for Data Analysis and Graphics (J H Maindonald)',
#        ' An Introduction to R: A Programming Environment for Data Analysis',
#        ' Applied Spatial Data Analysis with R (Roger S. Bivand, et al)',
#        ' A Handbook of Statistical Analyses Using R (Brian S. Everitt, et al)',
#        ' Using R for Introductory Statistics (John Verzani)',
#        ' Exploring Data Science (Nina Zumel, et al)',
#        ' Rails on Containers (Katherine Juell)',
#        " Programming Ruby: The Pragmatic Programmers' Guide",
#        ' Essential Ruby (Krzysztof Kowalczyk)',
#        ' Learn to Program (in Ruby), Second Edition (Chris Pine)',
#        ' Ruby Data Structures and Algorithms (Christopher Fox)',
#        ' Ruby Programming (Wikibooks)',
#        ' Using Blocks in Ruby: A Brain-Friendly Report (Jay McGavren)',
#        ' Learn Ruby the Hard Way: A Simple and Idiomatic Introduction',
#        ' I Love Ruby (Karthikeyan A K)',
#        ' Developing Games With Ruby (Tomas Varaneckas)',
#        ' Essential Ruby On Rails (Krzysztof Kowalczyk)',
#        ' Ruby on Rails Tutorial: Learn Web Development with Rails',
#        ' APIs on Rails - Building REST APIs with Rails (Abraham Kuri)',
#        ' Ruby Hacking Guide (Minero Aoki)',
#        ' Ruby Essentials (Neil Smyth)',
#        ' Rails Deep Dive (Glenn Goodrich)',
#        ' Objects on Rails (Avdi Grimm)',
#        ' The Bastards Book of Ruby (Dan Nguyen)',
#        ' Clever Algorithms: Nature-Inspired Programming Recipes in Ruby',
#        " Mr. Neighborly's Humble Little Ruby Book (Jeremy McAnally)",
#        ' Data Structures and Algorithms with OPP Design Patterns in Ruby',
#        ' Swift for Ruby Developers: An Tutorial Introduction',
#        " O'Reilly® MacRuby: The Definitive Guide: Ruby and Cocoa on OS X",
#        " O'Reilly® Rails 3 in a Nutshell: A Desktop Quick Reference",
#        ' The Book of Ruby: A Hands-On Guide for the Adventurous',
#        " O'Reilly® Ruby Best Practices (Gregory T Brown)",
#        ' Ruby on Rails Security Guide (OWASP Foundation)',
#        ' Getting Real: The Smarter, Faster, Easier Way to Build a Web',
#        ' Modern C (Jens Gustedt)',
#        ' Build Your Own Redis with C/C++ (James Smith)',
#        " Beej's Guide to C Programming (Brian Hall)",
#        " O'Reilly® Using C on the UNIX System (David A. Curry)",
#        ' Introduction to C and GUI Programming (Simon Long)',
#        ' Deep C (and C++) by Olve Maudal and Jon Jagger',
#        ' Programming Persistent Memory: A Comprehensive Guide',
#        ' Notes on Data Structures and Programming Techniques in C',
#        ' The C Book: Featuring the ANSI C Standard, 2nd Edition',
#        ' Learn to Code with C (Simon Long)',
#        ' The Art and Craft of Programming, C Edition (John C. Lusth)',
#        ' Object-Oriented Programming with ANSI-C (A. Schreiner)',
#        ' A Book on C: Programming in C (Al Kelley, et al.)',
#        ' Extreme C (Kamran Amini)', ' Practical C (Mark Hharrison)',
#        ' Learning C with Pebble (Mike Jipping)',
#        ' Scientific Programming and Computer Architecture',
#        ' How To Think Like A Computer Scientist: C Version',
#        ' Functional C (Pieter Hartel, Henk Muller )',
#        ' A to Z of C: The Evolving Book on C/DOS/Turbo C Programming',
#        ' C Programming Language and Software Design (Tim Bailey)',
#        ' Programming in C (Bharat Kinariwala, et al)',
#        ' C Programming (Wikibook)',
#        ' C Programming in Linux (David Haskins)',
#        ' The New C Standard: An Economic and Cultural Commentary',
#        ' C Programming Tutorial, 4th Edition (K&R Version), by Mark Burgess',
#        ' Programming in C - UNIX System Calls and Subroutines Using C',
#        ' 88 C Programs (JT Kalnay)',
#        ' Compiler Design in C (Allen I. Holub)',
#        ' Essential C (Krzysztof Kowalczyk)',
#        ' An Introduction to GCC: for the GNU Compilers GCC and G++',
#        ' How to Make a Computer Operating System Using C/C++',
#        ' C Elements of Style: Style Manual for Elegant C and C++ Programs',
#        ' Foundations of Computer Science, C Edition (Al Aho, et al)',
#        ' Memory Management: Algorithms and Implementations in C/C++',
#        ' What Every Programmer Should Know About Memory',
#        ' Pointers and Memory (Nick Parlante, et al.)',
#        ' Programming Pearls, 2nd Edition (Jon Bentley)',
#        ' C Programming for Arduino (Julien Bayle)',
#        ' Embedded Controllers Using C and Arduino (James Fiore)',
#        ' Programming Embedded Systems in C and C++ (Michael Barr)',
#        ' ANSI C for Programmers on UNIX Systems (Tim Love)',
#        ' The C Programming Language, 2nd Edition ©1988 (Brian Kernighan)',
#        ' Build Your Own Lisp (Daniel Holden)',
#        ' Haskell Tutorial for C Programmers (Eric Etheridge)',
#        ' Linkers and Loaders (John R. Levine)',
#        ' Code Connected Volume 1: Learning ZeroMQ (Pieter Hintjens)',
#        ' C++ For C Programmers (JT Kalnay)',
#        ' GNU Make: A Program for Directed Compilation',
#        ' PIC Microcontrollers - Programming in C (Milan Verle)',
#        ' Financial Applications using Excel Add-in in C/C++ (Dalton)',
#        ' Programming Embedded Systems using C (Mikael J. Pont)',
#        ' The GNU C Programming Tutorial (Mark Burgess)',
#        ' GNU C Library Application Fundamentals (Sandra Loosemore)',
#        ' GTK+/Gnome Application Development (Havoc Pennington)',
#        ' Conceptive C (Harry McGeough)',
#        ' Introduction to Programming for Image Analysis with VTK/C/C++',
#        " O'Reilly® Managing Projects with GNU Make (Mecklenburg)",
#        ' Excel Add-in Development in C/C++: Applications in Finance',
#        ' The Cg Tutorial: Guide to Programmable Real-Time Graphics ©2003',
#        ' Wireless Game Development in C/C++ with BREW (Barbagallo)',
#        ' Developing and Porting C and C++ Applications on Aix',
#        ' Virtual Machine Design and Implementation in C/C++',
#        ' Image Processing in C, 2nd Edition (Dwayne Philipps)',
#        ' Writing Bug-Free C Code: Automatically Detects Bugs in C Code',
#        ' No Bugs! Delivering Error-Free Code in C and C++ (Thielen)',
#        ' Numerical Recipes in C: The Art of Scientific Computing',
#        ' Scheme 9 from Empty Space: A Guide to Implementing Scheme in C',
#        ' Reverse Engineering for Beginners (Dennis Yurichev)',
#        ' Learn C The Hard Way: Modern C Programming (Zed Shaw)',
#        ' Modern C++ Tutorial: C++11/14/17/20 On the Fly (Changkun Ou)',
#        " O'Reilly® C++ Today: The Beast is Back (Jon Kalb, et al)",
#        ' Fundamentals of Programming C++ (Richard L. Halterman)',
#        ' Thinking in C++, Vol 1: Introduction to Standard C++ (2nd Edition)',
#        ' Thinking in C++, Vol 2: Practical Programming (Bruce Eckel)',
#        ' Build Your Own Redis with C/C++ (James Smith)',
#        ' Elements of Programming (Alexander Stepanov, et al)',
#        ' Data Structures and Algorithm Analysis in C++, 3rd Edition',
#        ' Data Parallel C++: Mastering DPC++ Programming',
#        ' Pro TBB: C++ Parallel Programming with Threading Building Blocks',
#        ' Programming Persistent Memory: A Comprehensive Guide',
#        ' Principles of Algorithmic Problem Solving using C++',
#        ' Scientific Programming and Computer Architecture',
#        " The Rook's Guide to C++ (Jeremy A. Hansen)",
#        ' C++ Annotations: An Extensive Tutorial (Frank B. Brokken)',
#        ' A Complete Guide to Programming in C++ (Ulla Kirch-Prinz, et al.)',
#        ' C++ Essentials (Sharam Hekmat)',
#        ' Object-Oriented Programming in C++, 4th Edition (Robert Lafore)',
#        ' The Boost C++ Libraries (Boris Schaling)',
#        ' Mastering OpenCV 4: A Comprehensive Guide with C++',
#        ' C++ Core Guidelines (Bjarne Stroustrup, et al)',
#        ' Practical C++ Metaprogramming (Edouard Alligand, et al)',
#        ' Practical Guide to Bare Metal C++ (Alex Robenko)',
#        ' More C++ Idioms (Wikibooks)',
#        ' Tips and Tricks of the C++ Professionals',
#        ' C++ Notes for Professionals',
#        ' Optimizing Software in C++ (Agner Fog)',
#        ' Essential C++ (Krzysztof Kowalczyk)',
#        ' The C++ Hackers Guide (Steve Oualline)',
#        ' Programming Fundamentals: A Structured Approach Using C++',
#        ' C++ For C Programmers (JT Kalnay)',
#        ' Programming Abstractions in C++ (Eric S. Roberts)',
#        ' Open Data Structures: An Introduction using C++ (Pat Morin)',
#        ' Structured Programming with C++ (Kjell Backman)',
#        ' An Introduction to the Imperative Part of C++',
#        ' An Introduction to GCC: for the GNU Compilers GCC and G++',
#        ' Programming Embedded Systems in C and C++ (Michael Barr)',
#        ' Learning Computing with Robots in C++ (Deepak Kumar)',
#        ' Reverse Engineering for Beginners (Dennis Yurichev)',
#        ' Computational Physics and Scientific Computing in C++',
#        " O'Reilly® Practical C++ Programming, 2nd Edition (Steve Oualline)",
#        ' Learn C++ Programming Language (Tutorials Point)',
#        ' How to Design Classes (Matthias Felleisen, et al)',
#        ' How to Make a Computer Operating System using C/C++',
#        ' C++ in Action: Industrial Strength Programming Techniques',
#        ' Industrial Strength C++: Rules and Recommendations',
#        ' C++ Programming for Scientists (Roldan Pozo, et at)',
#        ' Deep C (and C++) by Olve Maudal and Jon Jagger',
#        ' C++ Succinctly: C++ for C# Developers (M. McLaughlin)',
#        ' Memory Management: Algorithms and Implementations in C/C++',
#        ' What Every Programmer Should Know About Memory',
#        ' Pointers and Memory (Nick Parlante, et al.)',
#        ' Parallel Programming with Microsoft Visual C++ (Colin Campbell)',
#        ' Matters Computational: Ideas, Algorithms, Source Code in C++',
#        ' Programming Pearls, 2nd Edition (Jon Bentley)',
#        ' Code Connected Volume 1: Learning ZeroMQ (Pieter Hintjens)',
#        ' Financial Numerical Recipes in C++: Applications in Finance',
#        ' GNU Make: A Program for Directed Compilation',
#        ' Introduction to Design Patterns in C++ with Qt 4 (Alan Ezust)',
#        ' C++ GUI Programming with Qt 4, 2nd Edition (Jasmin Blanchette)',
#        ' How to Think Like a Computer Scientist, C++ Version (A. Downey)',
#        ' The InformIT C++ Reference Guide (Danny Kalev)',
#        ' Software Design Using C++ (David Carlson, et al)',
#        ' Cross-Platform GUI Programming with wxWidgets (Julian Smart)',
#        ' C++ GUI Programming with Qt 3 (Jasmin Blanchette)',
#        ' Programming With wxDev-C++ (Colin Laplace et al)',
#        ' C Elements of Style: Style Manual for Elegant C and C++ Programs',
#        " O'Reilly® Managing Projects with GNU Make (Robert Mecklenburg)",
#        ' Computer Science Tapestry: Exploring Programming in C++',
#        ' Optimizing C++ (Steve Heller)',
#        ' Optimizing C++: A Book about Improving Program Performance',
#        ' Data Structures and Algorithms with OPP Design Patterns in C++',
#        ' Developing and Porting C and C++ Applications on Aix',
#        ' Mastering C++ (K. R. Venugopal, et al)',
#        ' Compilers and Compiler Generators: An Introduction with C++',
#        ' Language Translation Using PCCTS and C++: A Reference Guide',
#        ' Teach Yourself C++ in 21 Days, 5th Edition (Jesse Liberty)',
#        ' Object-Oriented Programming in C++, 3rd Edition (Robert Lafore)',
#        ' C++ Neural Networks and Fuzzy Logic (Valluru B. Rao, et al)',
#        " C++: A Beginner's Guide, Second Edition (Herbert Schildt)",
#        ' Wireless Game Development in C/C++ with BREW (R. Barbagallo)',
#        ' Introduction to Programming for Image Analysis with VTK/C++',
#        ' Virtual Machine Design and Implementation in C/C++',
#        ' C++, A Dialog: Programming with the C++ Standard Library',
#        ' C++ Network Programming with ACE Frameworks (D. C. Schmidt)',
#        ' No Bugs! Delivering Error-Free Code in C and C++ (Thielen)',
#        ' Parallel and Distributed Programming Using C++ (Cameron Hughes)',
#        " ANSI/ISO C++ Professional Programmer's Handbook (Danny Kalev)",
#        ' Applied C++: Techniques for Building Better Software',
#        ' Modern Multithreading using Java, C++, and Win32 Programs',
#        ' Beginning C++ Programming (Richard Grimes)',
#        ' Creating Games in C++: A Step-by-Step Guide (David Conger)',
#        ' Financial Applications using Excel Add-in in C/C++ (Steve Dalton)',
#        ' Interfacing with C++: Programming Real-World Applications',
#        ' 3D Math Primer for Graphics and Game Development (F. Dunn)',
#        ' Beginning C++ Through Game Programming, 3rd Ed (M. Dawson)',
#        ' Rust for C++ Programmers (Nick Cameron)',
#        ' Hands-On System Programming with C++ (Dr. Rian Quinn)',
#        ' Lexical Analysis and Parsing using C++ (Bruno R. Preiss)',
#        ' Zero to MATLAB (Adam L. Lambert, PhD)',
#        ' Scientific Computing with MATLAB (Paul Gribble)',
#        ' An Introduction to Digital Signal Processing using MATLAB',
#        ' Experiments with MATLAB (Cleve Moler)',
#        ' Numerical Computing with MATLAB (Cleve B. Moler)',
#        ' Numerical Methods and MATLAB Programming for Engineers',
#        ' Physical Modeling in MATLAB (Allen B. Downey)',
#        ' Programming for Computations - MATLAB/Octave (Svein Linge)',
#        ' MATLAB for Engineers: Applications in Control, EE, IT and Robotics',
#        ' MATLAB Succinctly (Dmitri Nesteruk)',
#        ' Applications from Engineering with MATLAB Concepts',
#        ' MATLAB Applications for the Practical Engineer (Kelly Bennett)',
#        ' MATLAB - Modelling, Programming and Simulations (E. P. Leite)',
#        ' MATLAB: Tool for Scientific Computing and Engineering Apps, Vol 1',
#        ' MATLAB: Tool for Scientific Computing and Engineering Apps, Vol 2',
#        ' MATLAB: Tool for Scientific Computing and Engineering Apps, Vol 3',
#        ' Control Engineering: An Introduction with the Use of MATLAB',
#        ' MATLAB - A Ubiquitous Tool for the Practical Engineer (C. Ionescu)',
#        ' Engineering Education and Research Using MATLAB (Ali H. Assi)',
#        ' Applications of MATLAB in Science and Engineering (Michalowski)',
#        ' Scientific and Engineering Applications Using MATLAB (E. P. Leite)',
#        ' Neural Network Toolbox for MATLAB (Howard Demuth, et al)',
#        ' Biological Signal Analysis with MATLAB (R. Palaniappan)',
#        ' The TypeScript Handbook (Microsoft)',
#        ' Tackling TypeScript: Upgrading from JavaScript',
#        ' TypeScript in 50 Lessons (Stefan Baumgartner)',
#        ' TypeScript Deep Dive (Basarat Ali Syed)',
#        ' TypeScript Succinctly: The .NET approach to JavaScript',
#        ' TypeScript Accelerated (James Porter)',
#        ' Essential TypeScript (Krzysztof Kowalczyk)',
#        ' TypeScript Notes for Professionals',
#        ' TypeScript for C# Programmers (Steve Fenton)',
#        ' Scala Book (Alvin Alexander)',
#        ' Programming in Scala: A comprehensive step-by-step guide',
#        ' Creative Scala (Dave Gurnell, et al)',
#        ' Essential Scala (Noel Welsh, et al)',
#        ' Scala By Example (Martin Odersky)',
#        ' Scala with Cats (Noel Welsh, et al)',
#        ' Scala: A Pragmatic Programming Language',
#        ' Scala for the Impatient (Cay Horstmann)',
#        " O'Reilly® Lift Cookbook (Richard Dallaway)",
#        ' Exploring Lift (Derek Chen-Becker, et al)',
#        ' Simply Lift (David Pollak)',
#        ' Compiling Scala for the Java Virtual Machine (Michel Schinz)',
#        ' Scala Style Guide (Scala Community)',
#        " O'Reilly® Programming Scala: Scalability = Functional + Objects",
#        ' Learning Scala: Practical Functional Programming for the JVM',
#        ' Introduction to SQL (Bobby Iliev)',
#        ' SQL Performance Explained: Everything Developers Need to Know',
#        ' A Primer on SQL (Rahul Batra)',
#        ' SQL Queries Succinctly (Nick Harrison)',
#        ' SQL for Web Nerds (Philip Greenspun)',
#        ' Essential SQL (Krzysztof Kowalczyk)',
#        ' Structured Query Language (WikiBooks)',
#        ' Transact-SQL: The Building Blocks to SQL Server Programming',
#        ' Learn T-SQL Querying (Pedro Lopes, et al)',
#        ' SQL Notes for Professionals',
#        ' Developing Time-Oriented Database Applications in SQL',
#        ' Structured Query Language - A Practical Introduction (Akeel I. Din)',
#        ' SQL: A Comparative Survey, 2nd Edition (Hugh Darwen)',
#        ' Sams Teach Yourself SQL in 24 Hours (Ryan Stephens, et al)',
#        ' Database Design and Implementation using Oracle SQL',
#        ' Database Design with UML and SQL, 4th Edition (Alvaro Monge)',
#        ' Windows Azure SQL Reporting Succinctly (Stacia Misner)',
#        ' PostgreSQL 9.0 Reference - Volume 1A: The SQL Language',
#        ' PostgreSQL 9.0 Reference - Volume 1B: SQL Command Reference',
#        " Accounting Succinctly: A Developer's Guide (Joe Booth)",
#        ' Information Modeling: Specification and Implementation',
#        'How to Code in HTML5 and CSS3 (Damian Wielgosik)',
#        ' How To Build a Website With CSS and HTML (Erin Glass)',
#        ' Learn to Code HTML and CSS: Develop and Style Websites',
#        ' Responsive Web Design with HTML5 and CSS3 (Ben Frain)',
#        ' HTML5 in Action (Rob Crowther, et al)',
#        ' Dive Into HTML5 (Mark Pilgrim)',
#        ' HTML5 Programming Cookbook (Web Code Geeks)',
#        " HTML5 Shoot 'em Up in an Afternoon (Bryan Bibat)",
#        ' Essential HTML (Krzysztof Kowalczyk)',
#        ' HTML5 for Web Designers (Jeremy Keith)',
#        ' WebGL Insights (Patrick Cozzi)',
#        " O'Reilly® Web Audio API (Boris Smus)",
#        " O'Reilly® High Performance Browser Networking (Ilya Grigorik)",
#        ' Next Generation HTML5 and JavaScript (InfoQ)',
#        ' Modern Web Essentials Using JavaScript and HTML5 (David Pitt)',
#        ' HTML Canvas Deep Dive (Josh Marinacci)',
#        ' Essential HTML5 Canvas (Krzysztof Kowalczyk)',
#        " O'Reilly® HTML5: Up and Running (Mark Pilgrim)",
#        ' HTML Dog: HTML Tutorials. And Stuff (P. Griffiths)',
#        " O'Reilly® JavaScript and HTML5 Now (Kyle Simpson)",
#        " O'Reilly® Programming 3D Applications with HTML5 and WebGL",
#        " O'Reilly® HTML5 for Publishers (Sanders Kleinfeld)",
#        " O'Reilly® Enterprise Web Development: Building HTML5 Applications",
#        ' Learn HTML and CSS in One Easy to Use Guide (Shay Howe)',
#        ' HTML5 Graphing and Data Visualization Cookbook',
#        ' HTML5 and CSS3 For The Real World (Estelle Weyl, et al)',
#        ' Building Android Apps with HTML, CSS & JavaScript, 2nd Edition',
#        ' The Web Book: Guide to HTML, CSS, JavaScript, PHP and MySQL',
#        ' WML and WML Script (Vijay Mukhi)',
#        ' Building iPhone Apps with HTML, CSS, and JavaScript (J. Stark)',
#        " O'Reilly® Building Android Apps with HTML, CSS, and JavaScript",
#        ' SitePoint HTML Reference (Ian Lloyd)',
#        " O'Reilly® XForms Essentials (Micah Dubinko)",
#        " O'Reilly® Embedding Perl in HTML with Mason (Dave Rolsky)",
#        " O'Reilly® HTML and XHTML: The Definitive Guide (Chuck Musciano)",
#        ' Sams Teach Yourself HTML 4 in 24 Hours (Dick Oliver)',
#        ' Web SGML and HTML 4.0 Explained (Martin Bryan)',
#        ' Microsoft HTML and DHTML Reference © (Microsoft)',
#        ' Writing HTML: a Tutorial for Creating Web Pages (Alan Levine)',
#        ' HTML5 Canvas: Native Interactivity and Animation for the Web',
#        " Web Developer's Library Bookshelf: 5 Bestselling Books",
#        ' Why Rust? Trustworthy, Concurrent Systems Programming',
#        ' The Rust Programming Language (Steve Klabnik, et al)',
#        ' A Gentle Introduction To Rust (Steve J Donovan)',
#        ' Rust by Example (Rust Community)',
#        ' Rust for C++ Programmers (Nick Cameron)',
#        ' Perl 6 (Raku) at a Glance by Andrew Shitov',
#        ' Think Perl 6 (Raku): How to Think Like a Computer Scientist',
#        ' Using Perl 6 (Raku) by Jonathan S. Duff, et al',
#        ' Mastering Perl/Tk (Steve Lidie, et al)',
#        ' Higher-Order Perl: Transforming Programs with Programs',
#        " O'Reilly® Perl and LWP (Sean M. Burke)",
#        ' Beginning Perl (Simon Cozens)', ' Modern Perl (chromatic)',
#        " Beginning Perl (Curtis 'Ovid' Poe)",
#        ' Exploring Programming Language Architecture in Perl (Bill Hails)',
#        ' Perl for the Web (Chris Radcliff)',
#        ' Perl for System Administration: Managing Multi-platforms',
#        ' Unix and Perl Primer for Biologists (Keith Bradnam, et al)',
#        ' Learning PERL the Hard Way: Perl Programming for Beginners',
#        " O'Reilly® Practical mod_perl (Stas Bekman, Eric Cholet)",
#        " O'Reilly® Embedding Perl in HTML with Mason (Dave Rolsky, et al)",
#        ' CGI Programming 101: Programming Perl for the World Wide Web',
#        " O'Reilly® CGI Programming on the World Wide Web (Gundavaram)",
#        " O'Reilly® Web Client Programming with Perl (Clinton Wong)",
#        " O'Reilly® Mastering Perl, 2nd Edtion (Brian D Foyis)",
#        " O'Reilly® Extreme Programming with Perl (Robert Nagler)",
#        ' Practical Perl Programming (A. D. Marshall)',
#        ' Picking Up Perl, 2nd Edition (Bradley M. Kuhn, et al)',
#        ' Impatient Perl (Greg London)',
#        ' Perl for Beginners (Geoffrey Sampson)',
#        ' Learn Regex The Hard Way (Zed A. Shaw)',
#        ' Regular Expressions Succinctly (Joe Booth)',
#        ' The Perl CD Bookshelf, Version 4.0 - 6 Bestselling Books',
#        ' The Perl CD Bookshelf, Version 3.0 - 7 Bestselling Books',
#        ' The Perl CD Bookshelf, Version 2.0 - 5 Bestselling Books',
#        ' The Perl CD Bookshelf, Version 1.0 - 6 Bestselling Books',
#        ' Introduction to newLISP (WikiBooks)',
#        ' Practical Common Lisp (Peter Seibel)',
#        ' On Lisp: Advanced Techniques for Common Lisp (Paul Graham)',
#        ' Algorithmic Composition: Music Composition using Common LISP',
#        ' Common LISP - The Language, 2nd Edition (Guy L. Steele JR.)',
#        ' Lisp Hackers: Interviews with 100x More Productive Programmers',
#        ' Paradigms of Artificial Intelligence Programming: in Common Lisp',
#        ' Let Over Lambda - 50 Years of Lisp (Doug Hoyte)',
#        ' Successful Lisp: How to Understand and Use Common Lisp',
#        ' Common LISP: A Gentle Introduction to Symbolic Computation',
#        ' Common LISP: An Interactive Approach (Stuart Charles Shapiro)',
#        ' ANSI Common LISP (Paul Graham)',
#        ' Sketchy LISP: Introduction to Functional Programming',
#        ' Structure and Interpretation of Computer Programs, 2nd Edition',
#        ' AI Algorithms, Data Structures, and Idioms in Prolog, Lisp, and Java',
#        ' Practical Semantic Web and Linked Data Applications, LISP Edition',
#        ' Build Your Own Lisp (Daniel Holden)',
#        ' An Introduction to Programming in Emacs Lisp (Robert J. Chassell)',
#        ' GNU Emacs Lisp Reference Manual (Bil Lewis, et al)',
#        ' Exploring Randomness (Gregory J. Chaitin)',
#        ' Performance and Evaluation of Lisp Systems (Richard P. Gabriel)',
#        ' Lisp Primer (Colin Allen, et al)',
#        ' Zen-Style Programming (Nils M. Holm)',
#        ' The Limits of Mathematics (Gregory J. Chaitin)',
#        ' The Common Lisp Cookbook (Marco Antoniotti, et al)'],
#       dtype=object)
